# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

data=pd.read_csv('/kaggle/input/phishing/custom_phishing_dataset (1).csv')
print(data.head())
print("Rows and columns:",data.shape)
print("Missing values:\n",data.isnull().sum())
print("Target distribution:/n", data['Is_Phishing'].value_counts())
# Out:
#                                      URL  Have_IP  Have_At_Symbol  URL_Length  \
# 0               http://192.168.1.1/login        1               0          24
# 1                 https://www.google.com        0               0          22
# 2  http://phishingsite.com@malicious.com        0               1          38
# 3      http://example.com/update-account        0               0          33
# 4              https://secure.paypal.com        0               0          26
#
#    Is_Https  Is_Phishing
# 0         0            1
# 1         1            0
# 2         0            1
# 3         0            1
# 4         1            0
# Rows and columns: (10, 6)
# Missing values:
#  URL               0
# Have_IP           0
# Have_At_Symbol    0
# URL_Length        0
# Is_Https          0
# Is_Phishing       0
# dtype: int64
# Target distribution:/n Is_Phishing
# 1    6
# 0    4
# Name: count, dtype: int64

# %%
data.dropna(inplace=True)
X=data[['Have_IP','Have_At_Symbol','URL_Length','Is_Https']]
y=data['Is_Phishing']

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

#Split data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

#Train model

model=LogisticRegression()
model.fit(X_train, y_train)

#Evaluate

y_pred=model.predict(X_test)

print("Accuracy on test set:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy on test set: 1.0
